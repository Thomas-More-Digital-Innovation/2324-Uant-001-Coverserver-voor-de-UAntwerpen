# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
DATADIR = r"/content/drive/MyDrive/covers"  # Path naar data op google drive
# de subfolders worden automatisch herkend als labels
CATEGORIES = ["goede_covers", "slechte_covers"]  # Labels / Subfolders

# %%
img_height,img_width=300,200
batch_size=32
# Larger batch size may provide some computational speed-up but requires more memory
# Smaller batch sizes may offer better generalization, but training might be slower

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  DATADIR,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  )
# Out:
# Found 9507 files belonging to 2 classes.
# Using 7606 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  DATADIR,
  validation_split=0.2,  # 20% voor validation
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  image_count=10
  )
# Out:
# Found 9507 files belonging to 2 classes.
# Using 1901 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['goede_covers', 'slechte_covers']

# %%
resnet_model = Sequential()

pretrained_model= tf.keras.applications.ResNet50(include_top=False,
                   input_shape=(300,200,3),
                   pooling='avg',classes=1, # maxpooling kijken naar classes
                   weights='imagenet') # benchmark, de weights gebruiken van imagenetcompetition
for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
resnet_model.add(Flatten()) # is het flatten? globalavgpooling
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(1, activation='sigmoid'))

resnet_model.summary()
# Out:
# ...
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  module_wrapper (ModuleWrap  (None, 2048)              0
#  per)
#
#  module_wrapper_1 (ModuleWr  (None, 512)               1049088
#  apper)
#
#  module_wrapper_2 (ModuleWr  (None, 1)                 513
#  apper)
#
# ...
# Total params: 24637313 (93.98 MB)
# Trainable params: 1049601 (4.00 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
resnet_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
from keras.preprocessing import image
import os

DATADIR = r"/content/drive/MyDrive/covers"

all_files = []
for foldername, subfolders, filenames in os.walk(DATADIR):
    for filename in filenames:
        file_path = os.path.join(foldername, filename)
        all_files.append(file_path)

# Check and load each image
for file_path in all_files:
    try:
        print(f"Attempting to load image: {file_path}")
        img = image.load_img(file_path)
        print(f"Image loaded successfully: {file_path}")
    except Exception as e:
        # Print image path and the specific error
        print(f"Invalid Image: {file_path}, Error: {str(e)}")
# Out:
#   File "<ipython-input-34-03fba05d82b8>", line 15
#     except Exception as e:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 14

# %%
epochs=10
history = resnet_model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# er zijn afbeeldingen die niet .jpg zijn...
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-35-587e24af23d7> in <cell line: 2>()
#       1 epochs=10
# ----> 2 history = resnet_model.fit(
#       3   train_ds,
#       4   validation_data=val_ds,
#       5   epochs=epochs
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ...
